# %% [markdown]
# 1- https://github.com/dssg-pt/covid19pt-data
#
# 2- A nossa escolha incide sobre a temática generalizada da saúde, nomeadamente nos dados referentes ao Covid-19, uma vez que se apresenta algo bastante atual e interessante para a população em geral.
#
# 3- Consultar o ficheiro : "README-ANARITAHUGOMIGUELTOBBACK.md"
#
# 4- Para carregar o conjunto de dados utilizar o seguinte código: pd.read_csv("data.csv")
#                                                                     df = pd.read_csv("data.csv")
#     Para apresentar as 10 primeiras linhas do conjunto de dados utilizar o seguinte código: df.head(10)
#
# 5- O ficheiro CSV recorre a dados do tipo DataFrame ou TextParser (de acordo com a página fornecida pelo professor: "https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html%22)

# %%
#Para apresentar as 10 primeiras linhas de código
import csv
import numpy as np
import pandas as pd
pd.read_csv("data.csv")
df = pd.read_csv("data.csv") 
data = open("data.csv","r")
data = pd.read_csv(data,nrows=9)
df.head(10)
# Out:
#          data        data_dados  confirmados  confirmados_arsnorte  \
# 0  26-02-2020  26-02-2020 00:00            0                     0
# 1  27-02-2020  27-02-2020 00:00            0                     0
# 2  28-02-2020  28-02-2020 00:00            0                     0
# 3  29-02-2020  29-02-2020 00:00            0                     0
# 4  01-03-2020  01-03-2020 00:00            0                     0
# 5  02-03-2020  02-03-2020 00:00            2                     2
# 6  03-03-2020  03-03-2020 16:00            4                     2
# 7  04-03-2020  04-03-2020 17:00            6                     3
# 8  05-03-2020  05-03-2020 17:00            9                     5
# 9  06-03-2020  06-03-2020 17:00           13                     8
#
#    confirmados_arscentro  confirmados_arslvt  confirmados_arsalentejo  \
# 0                      0                   0                        0
# 1                      0                   0                        0
# ...
